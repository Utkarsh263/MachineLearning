# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from keras.models import Sequential
from keras.layers import  Dropout, Dense
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# **Generate Data**

# %%
X_train= np.linspace(-1,1,20)

# %%
y_train= np.array([0.43336, 0.83704, 0.77483, 0.20239, 0.592, 0.78075, 0.652, 0.30231, 0.25117, 0.27085, 0.65148, 0.81437, 0.54839, 0.43708, 0.72194, 0.53527, 0.86051, 0.8077, 0.00211, 0.7232
 ]
)

# %%
X_test= np.linspace(-1,1,20)

# %%
y_test=np.array([0.19041, 0.69227, 0.16074, 0.40297, 0.1186, 0.26941, 0.82344, 0.19823, 0.78065, 0.12108, 0.19719, 0.64867, 0.14652, 0.31979, 0.88405, 0.59123, 0.8874, 0.71475, 0.95003, 0.23314
])

# %%
plt.scatter(X_train,y_train,c='black', label='Train')
plt.scatter(X_test,y_test,c='red', label='Test')
plt.legend()
plt.show()

# %%
model=Sequential()
model.add(Dense(128, input_dim=1,activation='relu'))
model.add(Dense(128,activation='relu'))
model.add(Dense(1,activation='linear'))


adam=Adam(learning_rate=0.01)
model.compile(loss='mse',optimizer=adam,metrics=['mse'])

history= model.fit(X_train,y_train,validation_data=(X_test,y_test), epochs=500, verbose=True)
# Out:
# Epoch 1/500
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.3785 - mse: 0.3785 - val_loss: 0.0996 - val_mse: 0.0996
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.1212 - mse: 0.1212 - val_loss: 0.1570 - val_mse: 0.1570
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.1205 - mse: 0.1205 - val_loss: 0.2129 - val_mse: 0.2129
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.1477 - mse: 0.1477 - val_loss: 0.1660 - val_mse: 0.1660
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.1074 - mse: 0.1074 - val_loss: 0.1203 - val_mse: 0.1203
# Epoch 6/500
# ...

# %%
_, train_mse = model.evaluate(X_train, y_train, verbose=0)
_, test_mse = model.evaluate(X_test, y_test, verbose=0)
print('Train: {}, Test: {}'.format(train_mse, test_mse))
# Out:
# Train: 0.0024482302833348513, Test: 0.14624519646167755

# %%
y_pred= model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step

# %%
plt.figure(figsize=(10,6))
plt.scatter(X_train,y_train,c='black', label='Train')
plt.scatter(X_test,y_test,c='red', label='Test')
plt.plot(X_test,y_pred)
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model=Sequential()
model.add(Dense(128, input_dim=1,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1,activation='linear'))


adam=Adam(learning_rate=0.01)
model.compile(loss='mse',optimizer=adam,metrics=['mse'])

history= model.fit(X_train,y_train,validation_data=(X_test,y_test), epochs=500, verbose=True)
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.3564 - mse: 0.3564 - val_loss: 0.0977 - val_mse: 0.0977
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0975 - mse: 0.0975 - val_loss: 0.2414 - val_mse: 0.2414
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.2143 - mse: 0.2143 - val_loss: 0.1996 - val_mse: 0.1996
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.1322 - mse: 0.1322 - val_loss: 0.1239 - val_mse: 0.1239
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0760 - mse: 0.0760 - val_loss: 0.0977 - val_mse: 0.0977
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0855 - mse: 0.0855 - val_loss: 0.0938 - val_mse: 0.0938
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0679 - mse: 0.0679 - val_loss: 0.0901 - val_mse: 0.0901
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0747 - mse: 0.0747 - val_loss: 0.0842 - val_mse: 0.0842
# Epoch 9/500
# ...

# %%
_, train_mse = model.evaluate(X_train, y_train, verbose=0)
_, test_mse = model.evaluate(X_test, y_test, verbose=0)
print('Train: {}, Test: {}'.format(train_mse, test_mse))
# Out:
# Train: 0.03435112163424492, Test: 0.10818610340356827

# %%
y_pred=model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step

# %%
plt.figure(figsize=(10,6))
plt.scatter(X_train,y_train,c='black', label='Train')
plt.scatter(X_test,y_test,c='red', label='Test')
plt.plot(X_test,y_pred)
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
