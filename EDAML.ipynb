# %% [raw]
# #Univariate Analysis

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\utkar\\Downloads\\train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.sample()
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex  Age  SibSp  \
# 196          197         0       3  Mernagh, Mr. Robert  male  NaN      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 196      0  368703  7.75   NaN        Q

# %%
df.sample(10)
df.shape
# Out:
# (891, 12)

# %% [markdown]
# #Categorical Data
# a. Count Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x="Survived", data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
sns.countplot(x='Pclass', data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.countplot(df['Sex'])
# Out:
# <Axes: xlabel='count', ylabel='Sex'>

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
sns.countplot(df['Embarked'])
# Out:
# <Axes: xlabel='count', ylabel='Embarked'>

# %%
df['Embarked'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Embarked'>

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %% [markdown]
# #
# Pie Chart

# %%
sns.countplot(df['Survived'])
# Out:
# <Axes: ylabel='count'>

# %%
df['Survived'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# #Numerical Data

# %% [markdown]
# a. Histogram

# %%
plt.hist(df['Age'], bins=8)
# Out:
# (array([ 64., 115., 230., 155.,  86.,  42.,  17.,   5.]),
#  array([ 0.42  , 10.3675, 20.315 , 30.2625, 40.21  , 50.1575, 60.105 ,
#         70.0525, 80.    ]),
#  <BarContainer object of 8 artists>)

# %%
plt.hist(df['Age'], bins=20)
# Out:
# (array([40., 14., 15., 31., 79., 98., 85., 84., 73., 45., 35., 35., 29.,
#         16., 13., 11.,  4.,  5.,  1.,  1.]),
#  array([ 0.42 ,  4.399,  8.378, 12.357, 16.336, 20.315, 24.294, 28.273,
#         32.252, 36.231, 40.21 , 44.189, 48.168, 52.147, 56.126, 60.105,
#         64.084, 68.063, 72.042, 76.021, 80.   ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# b. distplot

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\utkar\AppData\Local\Temp\ipykernel_10428\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# c. Boxplot

# %%
# Outliers Minimum= Q1-1.5*IQR IQR= Interquartile Range Q1= 25% RABGE MEDIAN, Q3= 75TH PERCENTILE RANGE   Maximum

# %%
#Used to plot for noisy data
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].max()
# Out:
# 80.0

# %%
df['Age'].skew()
# Out:
# 0.38910778230082704

# %%
#If 0 then it is symmetrical in nature
#and if positive towards right side and negative towards left side

# %% [markdown]
# #Bivariate Analysis

# %%
tips= sns.load_dataset('tips')

# %%
flights=sns.load_dataset('flights')

# %%
iris= sns.load_dataset('iris')

# %% [markdown]
# ## ScatterPlot (Numerical - Numerical)

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#Linear relation in above graph

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, hue='sex', style='smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### Bar PLot (Numerical-Categorical)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.barplot(x='Pclass', y='Age',data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.barplot(x='Pclass', y='Fare', data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.barplot(x='Pclass', y='Fare', data=df, hue='Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# ## Box PLot( Numerical- Categorical)

# %%
sns.boxplot(x='Sex', y='Age', data=df, hue='Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# ## Distplot(Numerical- Categorical)

# %%
sns.distplot(df[df['Survived']==0]['Age'])
# Out:
# C:\Users\utkar\AppData\Local\Temp\ipykernel_10428\529285220.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Survived']==0]['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df[df['Survived']==0]['Age'])
sns.distplot(df[df['Survived']==1]['Age'])
# Out:
# C:\Users\utkar\AppData\Local\Temp\ipykernel_10428\1811681565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Survived']==0]['Age'])
# C:\Users\utkar\AppData\Local\Temp\ipykernel_10428\1811681565.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.distplot(df[df['Survived']==0]['Age'], hist=False)
sns.distplot(df[df['Survived']==1]['Age'], hist=False)
# Out:
# C:\Users\utkar\AppData\Local\Temp\ipykernel_10428\76854282.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Survived']==0]['Age'], hist=False)
# C:\Users\utkar\AppData\Local\Temp\ipykernel_10428\76854282.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# ## Heatmap( Categorical - Categorical)

# %%
pd.crosstab(df['Pclass'],df['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(df['Pclass'],df['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %% [markdown]
# ## Cluster Map(Categorical- Categorical)

# %%
#From Chatgppt

# %% [markdown]
# ## Pair Plot

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris, hue='species')

# %% [markdown]
# ## Line Plot

# %%
flights.groupby('year').sum().reset_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 flights.groupby('year').sum().reset_index()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:3146, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3141 else:
#    3142     # If we are grouping on categoricals we want unobserved categories to
#    3143     # return zero, rather than the default of NaN which the reindexing in
#    3144     # _agg_general() returns. GH #31422
#    3145     with com.temp_setattr(self, "observed", True):
# -> 3146         result = self._agg_general(
#    3147             numeric_only=numeric_only,
#    3148             min_count=min_count,
#    3149             alias="sum",
#    3150             npfunc=np.sum,
#    3151         )
#    3153     return self._reindex_output(result, fill_value=0)
#
# ...

# %%
sns.heatmap(flights.pivot_table(values='passengers', index='month', columns='year'))
# Out:
# C:\Users\utkar\AppData\Local\Temp\ipykernel_10428\1314982076.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.heatmap(flights.pivot_table(values='passengers', index='month', columns='year'))
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clusterplot(flights.pivot_table(values='passengers', index='month', columns='year'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 sns.clusterplot(flights.pivot_table(values='passengers', index='month', columns='year'))
#
# AttributeError: module 'seaborn' has no attribute 'clusterplot'

# %% [markdown]
# # Pandas Profiling Library

# %%
# !pip install pandas-profiling
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.7 MB ? eta -:--:--
#    ---- ----------------------------------- 0.5/4.7 MB 599.9 kB/s eta 0:00:08
#    ---- ----------------------------------- 0.5/4.7 MB 599.9 kB/s eta 0:00:08
#    ---- ----------------------------------- 0.5/4.7 MB 599.9 kB/s eta 0:00:08
#    ------ --------------------------------- 0.8/4.7 MB 486.4 kB/s eta 0:00:09
#    ------ --------------------------------- 0.8/4.7 MB 486.4 kB/s eta 0:00:09
#    -------- ------------------------------- 1.0/4.7 MB 466.2 kB/s eta 0:00:08
# ...

# %%
from pandas_profiling import ProfileReport
prof= ProfileReport(df)
prof.to_file(output_file= 'output.html')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 from pandas_profiling import ProfileReport
#       2 prof= ProfileReport(df)
#       3 prof.to_file(output_file= 'output.html')
#
# File ~\anaconda3\Lib\site-packages\pandas_profiling\__init__.py:6
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# File ~\anaconda3\Lib\site-packages\pandas_profiling\controller\pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 4 from pandas_profiling.profile_report import ProfileReport
# ...

# %%
# First, let's update or reinstall the required packages
# !pip install -U pandas-profiling
# !pip install -U numba

# If the above doesn't work, you can try using ydata-profiling instead
# (pandas-profiling was renamed to ydata-profiling)
# !pip install -U ydata-profiling

# Then use the updated import and code
from ydata_profiling import ProfileReport  # Updated import

# Create the profile report
prof = ProfileReport(df)

# Generate the output file
prof.to_file(output_file='output.html')
# Out:
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.8 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.8 MB 1.0 MB/s eta 0:00:03
#    ----------- ---------------------------- 0.8/2.8 MB 1.1 MB/s eta 0:00:02
#    -------------- ------------------------- 1.0/2.8 MB 968.5 kB/s eta 0:00:02
#    -------------- ------------------------- 1.0/2.8 MB 968.5 kB/s eta 0:00:02
#    ------------------ --------------------- 1.3/2.8 MB 849.7 kB/s eta 0:00:02
#    ------------------ --------------------- 1.3/2.8 MB 849.7 kB/s eta 0:00:02
#    ------------------ --------------------- 1.3/2.8 MB 849.7 kB/s eta 0:00:02
#    ---------------------- ----------------- 1.6/2.8 MB 710.8 kB/s eta 0:00:02
#    ---------------------- ----------------- 1.6/2.8 MB 710.8 kB/s eta 0:00:02
# ...
